# %% [markdown]
# <a href="https://colab.research.google.com/github/harleiaki/Nota_Enem/blob/main/Nota_Enem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Curso Data Science - Mundo Tech

# %% [markdown]
# ###**Trabalhando com a Biblioteca Pandas**

# %% [markdown]
# Pandas é uma biblioteca usada na linguagem Python, desenvolvida para manipulação e análise de dados.

# %%
import pandas as pd

# %% [markdown]
# ###**Importando o DataSet Enem 2019**

# %%
df = pd.read_csv('/content/drive/MyDrive/Nota_Enem/Dataset_ENEM_2019.csv', encoding='ISO-8859-1', delimiter=',')

# %%
df
# Out:
#         NOTA_CN  NOTA_CH  NOTA_LC  NOTA_MT  NOTA_REDACAO  NOTA_MEDIA  \
# 0         574.2    538.7    582.6    571.5         640.0     566.750
# 1         369.7    398.2    395.6    473.8         480.0     409.325
# 2         423.0    372.8    488.7    516.5         540.0     450.250
# 3         412.5    417.2    485.1    446.2         580.0     440.250
# 4         460.7    570.5    541.8    631.3         640.0     551.075
# ...         ...      ...      ...      ...           ...         ...
# 909189    533.3    485.8    530.2    595.5         540.0     536.200
# 909190    486.2    543.4    560.3    535.2         740.0     531.275
# 909191    500.8    563.2    555.3    442.8         780.0     515.525
# 909192    491.6    549.3    586.8    633.5         640.0     565.300
# 909193    425.7    525.0    511.5    621.8         620.0     521.000
#
#        TP_ESCOLA  IDADE SEXO  ESTADO_CIVIL  COR_RACA  TP_ENSINO  TREINEIRO  \
# ...

# %% [markdown]
# Visualizando Data Frame

# %%
df.head()
# Out:
#    NOTA_CN  NOTA_CH  NOTA_LC  NOTA_MT  NOTA_REDACAO  NOTA_MEDIA TP_ESCOLA  \
# 0    574.2    538.7    582.6    571.5         640.0     566.750   Privada
# 1    369.7    398.2    395.6    473.8         480.0     409.325   Pública
# 2    423.0    372.8    488.7    516.5         540.0     450.250   Pública
# 3    412.5    417.2    485.1    446.2         580.0     440.250   Pública
# 4    460.7    570.5    541.8    631.3         640.0     551.075   Pública
#
#    IDADE SEXO  ESTADO_CIVIL  COR_RACA  TP_ENSINO  TREINEIRO UF_ESC ESTUDO_PAI  \
# 0     18    F             1         1        1.0          0     PA          H
# 1     26    F             0         3        1.0          0     PA          B
# 2     17    F             1         3        1.0          0     PA          E
# 3     18    F             1         3        1.0          0     PA          E
# 4     17    M             1         3        1.0          0     PA          D
#
#   ESTUDO_MAE  PESSOAS_RESIDENCIA RENDA_MENSAL
# ...

# %%
df.head(15)
# Out:
#     NOTA_CN  NOTA_CH  NOTA_LC  NOTA_MT  NOTA_REDACAO  NOTA_MEDIA TP_ESCOLA  \
# 0     574.2    538.7    582.6    571.5         640.0     566.750   Privada
# 1     369.7    398.2    395.6    473.8         480.0     409.325   Pública
# 2     423.0    372.8    488.7    516.5         540.0     450.250   Pública
# 3     412.5    417.2    485.1    446.2         580.0     440.250   Pública
# 4     460.7    570.5    541.8    631.3         640.0     551.075   Pública
# 5     509.8    494.9    540.5    564.3         940.0     527.375   Pública
# 6     422.1    534.4    516.3    585.2         480.0     514.500   Pública
# 7     450.9    436.6    489.1    408.4         580.0     446.250   Pública
# 8     501.3    534.3    539.7    545.1         740.0     530.100   Pública
# 9     407.4    364.8    487.2    377.9         560.0     409.325   Pública
# 10    550.8    618.4    606.8    635.5         800.0     602.875   Pública
# ...

# %%
df.tail()
# Out:
#         NOTA_CN  NOTA_CH  NOTA_LC  NOTA_MT  NOTA_REDACAO  NOTA_MEDIA  \
# 909189    533.3    485.8    530.2    595.5         540.0     536.200
# 909190    486.2    543.4    560.3    535.2         740.0     531.275
# 909191    500.8    563.2    555.3    442.8         780.0     515.525
# 909192    491.6    549.3    586.8    633.5         640.0     565.300
# 909193    425.7    525.0    511.5    621.8         620.0     521.000
#
#        TP_ESCOLA  IDADE SEXO  ESTADO_CIVIL  COR_RACA  TP_ENSINO  TREINEIRO  \
# 909189   Pública     17    F             1         1        1.0          0
# 909190   Pública     18    F             1         1        1.0          0
# 909191   Pública     18    F             1         2        1.0          0
# 909192   Pública     18    F             1         3        1.0          0
# 909193   Pública     17    F             1         3        1.0          0
#
#        UF_ESC ESTUDO_PAI ESTUDO_MAE  PESSOAS_RESIDENCIA RENDA_MENSAL
# ...

# %%
df[30:35]
# Out:
#     NOTA_CN  NOTA_CH  NOTA_LC  NOTA_MT  NOTA_REDACAO  NOTA_MEDIA TP_ESCOLA  \
# 30    492.2    518.9    571.4    427.0         540.0     502.375   Pública
# 31    496.1    619.6    563.5    540.6         920.0     554.950   Pública
# 32    559.6    618.7    607.5    615.6         900.0     600.350   Pública
# 33    508.9    551.0    564.9    565.2         520.0     547.500   Pública
# 34    487.9    518.7    494.3    563.1         500.0     516.000   Pública
#
#     IDADE SEXO  ESTADO_CIVIL  COR_RACA  TP_ENSINO  TREINEIRO UF_ESC  \
# 30     18    M             1         1        1.0          0     PA
# 31     17    F             0         1        1.0          0     PA
# 32     18    F             1         3        1.0          0     PA
# 33     21    M             1         1        1.0          0     PA
# 34     18    M             1         3        1.0          0     PA
#
#    ESTUDO_PAI ESTUDO_MAE  PESSOAS_RESIDENCIA RENDA_MENSAL
# ...

# %%
df['TP_ESCOLA']
# Out:
# 0         Privada
# 1         Pública
# 2         Pública
# 3         Pública
# 4         Pública
#            ...
# 909189    Pública
# 909190    Pública
# 909191    Pública
# 909192    Pública
# 909193    Pública
# Name: TP_ESCOLA, Length: 909194, dtype: object

# %%
df['TP_ESCOLA'][30:35]
# Out:
# 30    Pública
# 31    Pública
# 32    Pública
# 33    Pública
# 34    Pública
# Name: TP_ESCOLA, dtype: object

# %%
df['TP_ESCOLA'].unique()
# Out:
# array(['Privada', 'Pública'], dtype=object)

# %%
df['TP_ESCOLA'].value_counts()
# Out:
# Pública    785009
# Privada    124185
# Name: TP_ESCOLA, dtype: int64

# %%
df['TP_ESCOLA'].value_counts(normalize=True)
# Out:
# Pública    0.863412
# Privada    0.136588
# Name: TP_ESCOLA, dtype: float64

# %%
df[['TP_ESCOLA','NOTA_REDACAO']]
# Out:
#        TP_ESCOLA  NOTA_REDACAO
# 0        Privada         640.0
# 1        Pública         480.0
# 2        Pública         540.0
# 3        Pública         580.0
# 4        Pública         640.0
# ...          ...           ...
# 909189   Pública         540.0
# 909190   Pública         740.0
# 909191   Pública         780.0
# 909192   Pública         640.0
# 909193   Pública         620.0
#
# [909194 rows x 2 columns]

# %% [markdown]
# ###**Análise Exploratória**

# %% [markdown]
# #### Estatística Descritiva

# %% [markdown]
# #### Medidas de Tendência Central

# %%
df.NOTA_CN.max()
# Out:
# 853.5

# %%
df.NOTA_CN.min()
# Out:
# 0.0

# %%
df.NOTA_CN.mean()
# Out:
# 475.50779866563124

# %%
df.NOTA_CN.median()
# Out:
# 467.7

# %%
df.NOTA_CN.mode()
# Out:
# 0    424.2
# Name: NOTA_CN, dtype: float64

# %% [markdown]
# #### Medidas de Dispersão

# %%
#Amplitude
df.NOTA_CN.max() - df.NOTA_CN.min()
# Out:
# 853.5

# %%
df.NOTA_CN.var()
# Out:
# 5712.446098478061

# %%
df.NOTA_CN.std()
# Out:
# 75.58072570753777

# %%
df[['TP_ESCOLA', 'NOTA_CN']].groupby('TP_ESCOLA').describe()
# Out:
#             NOTA_CN
#               count        mean        std  min    25%    50%    75%    max
# TP_ESCOLA
# Privada    124185.0  550.197863  74.869586  0.0  505.9  561.0  600.7  853.5
# Pública    785009.0  463.692156  68.609453  0.0  409.7  456.3  513.9  842.8

# %%
import matplotlib.pyplot as plt

# %%
df.TP_ESCOLA.value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# › Nota de Ciências Humanas
#
# › Nota de Linguagens e Códigos
#
# › Nota de Matemática
#
# › Nota de Redação

# %%
df[['TP_ESCOLA', 'NOTA_CH']].groupby('TP_ESCOLA').describe()
# Out:
#             NOTA_CH
#               count        mean        std  min    25%    50%    75%    max
# TP_ESCOLA
# Privada    124185.0  578.255813  73.548928  0.0  539.5  588.5  627.9  808.3
# Pública    785009.0  496.758587  75.374766  0.0  441.7  500.2  552.7  835.1

# %%
df[['TP_ESCOLA', 'NOTA_LC']].groupby('TP_ESCOLA').describe()
# Out:
#             NOTA_LC
#               count        mean        std  min    25%    50%    75%    max
# TP_ESCOLA
# Privada    124185.0  572.492241  52.163264  0.0  545.6  579.7  607.1  801.7
# Pública    785009.0  512.357077  61.189835  0.0  476.8  519.0  555.6  749.6

# %%
df[['TP_ESCOLA', 'NOTA_MT']].groupby('TP_ESCOLA').describe()
# Out:
#             NOTA_MT
#               count        mean         std  min    25%    50%    75%    max
# TP_ESCOLA
# Privada    124185.0  637.746374  116.957044  0.0  555.6  648.8  721.6  985.5
# Pública    785009.0  509.751873   96.689717  0.0  433.2  491.0  574.0  985.0

# %% [markdown]
# Notas de Matemática Enem 2019.

# %%
df[['TP_ESCOLA', 'NOTA_REDACAO']].groupby('TP_ESCOLA').describe()
# Out:
#           NOTA_REDACAO                                                    \
#                  count        mean         std  min    25%    50%    75%
# TP_ESCOLA
# Privada       124185.0  742.820147  152.708542  0.0  640.0  760.0  860.0
# Pública       785009.0  564.841957  182.482117  0.0  480.0  580.0  660.0
#
#
#               max
# TP_ESCOLA
# Privada    1000.0
# Pública    1000.0

# %% [markdown]
# Notas das Redações Enem 2019, diferenças Escola Pública e Privada.

# %% [markdown]
# df.mean() Retorna a média de todas as colunas.
#
# df.corr() Retorna a correlação entre as colunas de um Data Frame.
#
# df.count() Retorna o número de valores não nulos em cada coluna do Data Frame.
#
# df.max() Retorna o maior valor em cada coluna.
#
# df.min() Retorna o menor valor em cada coluna.
#
# df.median() Retorna a mediana de cada coluna.
#
# df.std() Retorna o desvio padrão de cada coluna
